# %% [markdown]
# # Magic Commands Use Cases
# _**The Purpose of doing the use case practices.**_
#
# <span style="color:blue">This text is blue</span>
#
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
--Task2: Create a volume namely usage_metrics using sql magic command %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %run "/Workspace/Users/91mohans@gmail.com/GM Local Notebook/4_child_nb_dataload"

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics

# %%
# %fs head dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

# %%
# %python 
df1.write.saveAsTable("default.mobile_os_usage")

# %%
# %sql
Select * from default.mobile_os_usage;

# %%
var1 = input("Enter the text")
print(var1.upper())

# %%
# %pip install pandas

# %%
import pandas as pd
df1 = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

# %%
# %sh
echo "Magic commands tasks completed"
